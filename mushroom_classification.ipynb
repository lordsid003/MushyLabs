# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_style("white")

# %% [markdown]
# ## Loading and understanding dataset

# %%
df = pd.read_csv("./Datasets/mushrooms.csv")
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
print(f"Training Dataset Dimensions: {df.shape}")
df.info()
# Out:
# Training Dataset Dimensions: (8124, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
for i in range(df.shape[1]):
    df[df.columns[i]] = label_encoder.fit_transform(df.iloc[:, i])

# %%
df.sample(5)
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 5407      1          5            2          0        1     2
# 6282      1          5            3          2        0     2
# 6039      1          2            2          4        0     8
# 4059      0          5            0          2        1     5
# 3166      1          5            0          3        0     2
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 5407                1             0          0          10  ...
# 6282                1             0          1           0  ...
# 6039                1             0          1           0  ...
# 4059                1             0          0           5  ...
# 3166                1             0          0           7  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 5407                         0                       7
# 6282                         1                       7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %% [markdown]
# ## Splitting Dataset into Training and Testing sets

# %%
X = df.iloc[:, 1:].to_numpy()
y = df.iloc[:, 0].to_numpy()
print(f"X_matrix_dimensions: {X.shape}")
print(f"y_vector_dimensions: {y.shape}")
# Out:
# X_matrix_dimensions: (8124, 22)
# y_vector_dimensions: (8124,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(f"x_train_shape: {x_train.shape}, y_train_shape: {y_train.shape}")
print(f"x_test_shape: {x_test.shape}, y_test_shape: {y_test.shape}")
# Out:
# x_train_shape: (6499, 22), y_train_shape: (6499,)
# x_test_shape: (1625, 22), y_test_shape: (1625,)

# %% [markdown]
# ## Data Visualization

# %%
plt.figure(figsize=(20, 14))
sns.heatmap(df.corr(), cmap="Blues", annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
sns.histplot(df.iloc[:, 8], kde=True)
# Out:
# <Axes: xlabel='gill-size', ylabel='Count'>

# %% [markdown]
# ## Model Training (Mathematical modelling)

# %%
def sigmoid(x):
    return (1 / (1 + np.exp(-x)))

# %%
example_vector = np.arange(-10, 11)
example_vector = sigmoid(example_vector)
plt.plot(example_vector)
plt.title("Sigmoid Activation Function")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
def compute_cost(x, y, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    loss = 0.0
    for i in range(m):
        f_wb[i] = np.dot(w, x[i]) + b
        f_wb[i] = sigmoid(f_wb[i])
        loss += - (y[i] * np.log(f_wb[i])) - ((1 - y[i]) * np.log(1 - f_wb[i]))
    loss /= (2 * m)
    return loss

# %%
def compute_gradient(x, y, w, b):
    m, n = x.shape
    f_wb = np.zeros(m)
    dj_dw = np.zeros(n)
    dj_db = 0.0
    error = 0.0
    for i in range(m):
        f_wb[i] = np.dot(w, x[i]) + b
        f_wb[i] = sigmoid(f_wb[i])
        error = (f_wb[i] - y[i])
        for j in range(n):
            dj_dw[j] += (error * x[i, j])
        dj_db += error
    dj_dw /= m
    dj_db /= m
    return dj_dw, dj_db

# %%
import copy, math

# %%
def gradient_descent(x, y, w_in, b_in, cost_func, gradient_func, alpha, num_iters):
    w = copy.deepcopy(w_in)
    b = b_in
    j_history = []
    w_history = []
    b_history = []
    for i in range(num_iters):
        dj_dw, dj_db = gradient_func(x, y, w, b)
        w -= alpha * dj_dw
        b -= alpha * dj_db
        if i < 100000:
            loss = cost_func(x, y, w, b)
            j_history.append(loss)
        if((i % math.ceil(num_iters / 10) == 0) or (i == num_iters - 1)):
            w_history.append(w)
            b_history.append(b)
            print(f"Iterations: {i} ===> Loss: {j_history[-1]}")
    return w, b, j_history, w_history, b_history

# %%
w_initial = np.zeros((1, x_train.shape[1]))
b_initial = 0.01
alpha = 1e-2
iterations = 50000

w_final, b_final, loss, weights, bias = gradient_descent(x_train, y_train, w_initial, b_initial, compute_cost,
                                                         compute_gradient, alpha, iterations)
print(f"Trained Parameters:")
print(f"Weights: {w_final.tolist()}, Bias: {b_final}")
# Out:
# Iterations: 0 ===> Loss: 0.3395515518225486
# Iterations: 5000 ===> Loss: 0.1280213508413065
# Iterations: 10000 ===> Loss: 0.11292983034326672
# Iterations: 15000 ===> Loss: 0.10583563874160279
# Iterations: 20000 ===> Loss: 0.10166490926666713
# Iterations: 25000 ===> Loss: 0.09888816490229659
# Iterations: 30000 ===> Loss: 0.09688480572421454
# Iterations: 35000 ===> Loss: 0.09535582877979219
# Iterations: 40000 ===> Loss: 0.0941393641093116
# Iterations: 45000 ===> Loss: 0.09314007646378744
# Iterations: 49999 ===> Loss: 0.09229829962606823
# Trained Parameters:
# ...

# %% [markdown]
# ## Model Evaluation

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
plots = [loss, weights[0][0], bias]
labels = ["Loss", "Weights", "Bias"]
for i in range(3):
    ax[i].plot(plots[i])
    ax[i].set_title(f"{labels[i]} vs Epochs")
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(labels[i].upper())
plt.subplots_adjust(wspace=0.2)
plt.suptitle("Metrics Evaluation", fontsize=15)
plt.show()

# %% [markdown]
# ## Accuracy on Training Data

# %%
def prediction_matrix(x, w=w_final, b=b_final):
    m = x.shape[0]
    p = np.zeros(m)
    for i in range(m):
        p[i] = np.dot(w, x[i]) + b
        p[i] = sigmoid(p[i])
        if p[i] >= 0.5:
            p[i] = 1
        else:
            p[i] = 0
    return p

# %%
def accuracy(x, y):
    m = x.shape[0]
    acc = 0.0
    for i in range(m):
        if x[i] == y[i]:
            acc += 1
    acc /= m
    return acc

# %%
x_train_predictions = prediction_matrix(x_train)
x_train_accuracy = accuracy(x_train_predictions, y_train)
print(f"Training set accuracy: {x_train_accuracy * 100}%")
# Out:
# Training set accuracy: 94.59916910293892%

# %%
x_train_predictions[1500], y_train[1500]
# Out:
# (1.0, 1)

# %% [markdown]
# ## Performance metrics on Testing Data

# %%
x_test_predictions = prediction_matrix(x_test)
x_test_accuracy = accuracy(x_test_predictions, y_test)
print(f"Testing set accuracy: {x_test_accuracy * 100}%")
# Out:
# Testing set accuracy: 94.64615384615385%

# %%
x_test_predictions[1500], y_test[1500]
# Out:
# (0.0, 0)

# %%
# Trained Parameters:
# Weights: [[-0.024956462776365873, 0.48290496052189424, -0.03870427179681009, -0.9975030460757535, 
#            -0.2848756413600517, 0.6723778007493697, -3.273385514481454, 4.491796755394252,
#            -0.12761211765843392, -0.80845330343299, -1.1575220884027035, -2.508206876120097, 
#            -0.4197560564248292, -0.10480028817720448, -0.034035227772658674, 0.0, 3.1199435284876182,
#            -0.6983902666978163, 0.40064004211711884, -0.14502170235576434, 0.06560835482410922, 0.1792180262947948]], 
# Bias: 0.8453068080484111

# %% [markdown]
# ## Making predictions

# %%
def predict(x, w=w_final, b=b_final):
    p = np.dot(w, x) + b
    p = sigmoid(p)
    if p >= 0.5:
        p = 1
    else:
        p = 0
    return p

# %%
predict(x_test[110]), y_test[110]
# Out:
# (0, 0)
